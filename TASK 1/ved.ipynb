# %%
import pandas as pd 
v1=pd.read_csv('Question1.csv')
v1.head()
# Out:
#    Sr.No. Company Name      Model Name             Fuel Type Body Style  \
# 0       1       Toyota         Corolla                Petrol      Sedan
# 1       2        Honda           Civic                Petrol      Sedan
# 2       3      Hyundai             i20                Petrol  Hatchback
# 3       4          Kia             i21                Diesel        SUV
# 4       5        Tesla  Model S Plaid+  EV(Electriv Vehicle)      Sedan
#
#   Car Length
# 0    4620 mm
# 1     4556mm
# 2     3995mm
# 3     4315mm
# 4     4970mm

# %%
import pandas as pd 
v2=pd.read_excel('Question2.xlsx')
v2.head()
# Out:
#    Sr.No Company Name   Model Name On road pricing Loan amount Monthly EMI  \
# 0      1       Toyota    Supra MK4         85 lakh      5 lakh        50 k
# 1      2       Nissan       GTR-S7         70 lakh      4 lakh        45 k
# 2      3         Ford       Fusion         67 lakh    3.8 lakh        45 k
# 3      4        Tesla  TeslaTronic         80 lakh    4.6 lakh        50 k
# 4      5       Suzuki   SwiftDzire         35 lakh    1.5 lakh        30 k
#
#    Interest Rate Monthly Principal Monthly Interest
# 0          0.040              50 k             12k
# 1          0.040              42 k             10 k
# 2          0.037              43 k             11 k
# 3          0.039              48 k              9 k
# 4          0.030              31 k              7 k

# %%
import pandas as pd
v1=pd.read_csv('Question1.csv')
print(v1)

v2=pd.read_excel('Question2.xlsx')
print(v2)

v=pd.merge(v1,v2,on='Company Name')
v.head()
# Out:
#    Sr.No. Company Name      Model Name             Fuel Type Body Style  \
# 0       1       Toyota         Corolla                Petrol      Sedan
# 1       2        Honda           Civic                Petrol      Sedan
# 2       3      Hyundai             i20                Petrol  Hatchback
# 3       4          Kia             i21                Diesel        SUV
# 4       5        Tesla  Model S Plaid+  EV(Electriv Vehicle)      Sedan
#
#   Car Length
# 0    4620 mm
# 1     4556mm
# 2     3995mm
# 3     4315mm
# 4     4970mm
#    Sr.No       Company Name   Model Name On road pricing Loan amount  \
# 0      1             Toyota    Supra MK4         85 lakh      5 lakh
# 1      2             Nissan       GTR-S7         70 lakh      4 lakh
# 2      3               Ford       Fusion         67 lakh    3.8 lakh
# 3      4              Tesla  TeslaTronic         80 lakh    4.6 lakh
# 4      5             Suzuki   SwiftDzire         35 lakh    1.5 lakh
# ...

# %%
import pandas as pd
v1=pd.read_csv('Question1.csv')
print(v1)

v2=pd.read_excel('Question2.xlsx')
print(v2)

v.fillna(0,inplace=True)
v.head()
# Out:
#    Sr.No. Company Name      Model Name             Fuel Type Body Style  \
# 0       1       Toyota         Corolla                Petrol      Sedan
# 1       2        Honda           Civic                Petrol      Sedan
# 2       3      Hyundai             i20                Petrol  Hatchback
# 3       4          Kia             i21                Diesel        SUV
# 4       5        Tesla  Model S Plaid+  EV(Electriv Vehicle)      Sedan
#
#   Car Length
# 0    4620 mm
# 1     4556mm
# 2     3995mm
# 3     4315mm
# 4     4970mm
#    Sr.No       Company Name   Model Name On road pricing Loan amount  \
# 0      1             Toyota    Supra MK4         85 lakh      5 lakh
# 1      2             Nissan       GTR-S7         70 lakh      4 lakh
# 2      3               Ford       Fusion         67 lakh    3.8 lakh
# 3      4              Tesla  TeslaTronic         80 lakh    4.6 lakh
# 4      5             Suzuki   SwiftDzire         35 lakh    1.5 lakh
# ...

# %%
import pandas as pd
v1=pd.read_csv('Question1.csv')
v1.head()

v2=pd.read_excel('Question2.xlsx')
v2.head()

for index,row in v2.iterrows():
    print(row["On road pricing"])
# Out:
# 85 lakh
# 70 lakh
# 67 lakh
# 80 lakh
# 35 lakh
# 30 lakh
# 45 lakh
# 30 lakh
# 40 lakh
# 50 lakh

# %%
import pandas as pd
v1=pd.read_csv('Question1.csv')
print(v1)

v2=pd.read_excel('Question2.xlsx')
print(v2)

v=pd.merge(v1,v2,on='Company Name')
v.head()

for index,row in v.iterrows():
    v.at[index,'On road pricing'] +=row['GST']
v.head()
# Out:
#    Sr.No. Company Name      Model Name             Fuel Type Body Style  \
# 0       1       Toyota         Corolla                Petrol      Sedan
# 1       2        Honda           Civic                Petrol      Sedan
# 2       3      Hyundai             i20                Petrol  Hatchback
# 3       4          Kia             i21                Diesel        SUV
# 4       5        Tesla  Model S Plaid+  EV(Electriv Vehicle)      Sedan
#
#   Car Length
# 0    4620 mm
# 1     4556mm
# 2     3995mm
# 3     4315mm
# 4     4970mm
#    Sr.No       Company Name   Model Name On road pricing Loan amount  \
# 0      1             Toyota    Supra MK4         85 lakh      5 lakh
# 1      2             Nissan       GTR-S7         70 lakh      4 lakh
# 2      3               Ford       Fusion         67 lakh    3.8 lakh
# 3      4              Tesla  TeslaTronic         80 lakh    4.6 lakh
# 4      5             Suzuki   SwiftDzire         35 lakh    1.5 lakh
# ...
